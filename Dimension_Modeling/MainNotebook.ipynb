# %%
# %run /Users/pradeepti239@gmail.com/WeatherNew/City_dim
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %run /Users/pradeepti239@gmail.com/WeatherNew/Date_dim
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %run /Users/pradeepti239@gmail.com/WeatherNew/Time_dim
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>timeID</th></tr></thead><tbody><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>4</td></tr><tr><td>5</td></tr><tr><td>6</td></tr><tr><td>7</td></tr><tr><td>8</td></tr><tr><td>9</td></tr><tr><td>10</td></tr><tr><td>11</td></tr><tr><td>12</td></tr><tr><td>13</td></tr><tr><td>14</td></tr><tr><td>15</td></tr><tr><td>16</td></tr><tr><td>17</td></tr><tr><td>18</td></tr><tr><td>19</td></tr><tr><td>20</td></tr><tr><td>21</td></tr><tr><td>22</td></tr><tr><td>23</td></tr><tr><td>24</td></tr></tbody></table></div>
# +------+---------+--------+
# |timeID|startHour| endHour|
# ...

# %%
# %run /Users/pradeepti239@gmail.com/WeatherNew/Weather_dim
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>lat</th><th>lon</th><th>name</th><th>country</th></tr></thead><tbody><tr><td>1282616.0</td><td>27.98333</td><td>83.76667</td><td>Wāliṅ</td><td>NP</td></tr><tr><td>1282621.0</td><td>27.766666</td><td>84.566666</td><td>Upardang Gadhi</td><td>NP</td></tr><tr><td>1282635.0</td><td>28.130989</td><td>82.297256</td><td>Tulsīpur</td><td>NP</td></tr><tr><td>1282665.0</td><td>27.633333</td><td>84.5</td><td>Tikoli</td><td>NP</td></tr><tr><td>1282666.0</td><td>28.5</td><td>81.133331</td><td>Ṭikāpur</td><td>NP</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
# ...

# %%
# %run /Users/pradeepti239@gmail.com/WeatherNew/WeatherDataHourly

# %%
weather_fact_hourly_df = spark.read.parquet("dbfs:/tmp/weather_fact_hourly.parquet")
weather_fact_hourly_df = weather_fact_hourly_df.dropDuplicates()
display(weather_fact_hourly_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %run /Users/pradeepti239@gmail.com/WeatherNew/WeatherDataDaily
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
weather_fact_daily_df = spark.read.parquet("dbfs:/tmp/weather_fact_daily.parquet")

weather_fact_daily_df = weather_fact_daily_df.dropDuplicates()
display(weather_fact_daily_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
