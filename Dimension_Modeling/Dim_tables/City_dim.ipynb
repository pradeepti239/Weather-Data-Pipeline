# %%
city_dim = spark.read.format("delta").load("/user/hive/warehouse/cities")

# %%
display(city_dim)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
city_dim.write.mode("overwrite").parquet("/tmp/city_dim.parquet")
